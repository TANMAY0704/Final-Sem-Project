# %%
pip install yfinance numpy pandas scikit-learn tensorflow streamlit requests matplotlib seaborn
# Out:
# Requirement already satisfied: yfinance in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (0.2.54)
# Requirement already satisfied: numpy in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (1.6.1)
# Collecting tensorflow
#   Using cached tensorflow-2.19.0-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: streamlit in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (1.43.2)
# Requirement already satisfied: requests in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (2.32.3)
# Requirement already satisfied: matplotlib in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (0.13.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: setuptools in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (19.0.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: colorama in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: rich in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.19.0-cp311-cp311-win_amd64.whl (375.9 MB)
# Installing collected packages: tensorflow
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\pande\\anaconda3\\envs\\MachineLearning\\Lib\\site-packages\\tensorflow\\compiler\\mlir\\lite\\python\\_pywrap_converter_api.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import yfinance as yf

def get_stock_data(ticker, start="2010-01-01"):
    data = yf.download(ticker, start=start)
    data = data[['Close']]
    return data

ticker = "TCS.NS"
df = get_stock_data(ticker)
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close
# Ticker          TCS.NS
# Date
# 2010-01-04  288.089172
# 2010-01-05  288.165741
# 2010-01-06  281.650177
# 2010-01-07  273.812134
# 2010-01-08  268.216309

# %%
import http.client
import json

# Connect to API
conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "d3660ac08cmsh7ef855175840569p1828b7jsnb8a720203fb4",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

# API Request
conn.request("GET", "/api/news/list-by-symbol?s=AAPL%2CGOOGL%2CTSLA&region=US&snippetCount=5", headers=headers)
res = conn.getresponse()
data = res.read()

# Convert JSON response
try:
    news_data = json.loads(data.decode("utf-8"))  # Convert response to dictionary
except json.JSONDecodeError as e:
    print("Error parsing JSON:", e)
    exit()

# Extract & display news
if "data" in news_data and "main" in news_data["data"] and "stream" in news_data["data"]["main"]:
    articles = news_data["data"]["main"]["stream"]  # Extract list of articles

    for item in articles:
        content = item.get("content", {})  # Extract content dictionary
        title = content.get("title", "No Title")  # Extract title

        # Ensure URL exists before extracting it
        click_url = content.get("clickThroughUrl")
        link = click_url["url"] if click_url and "url" in click_url else None

        if not link:
            continue  # Skip articles with no valid link

        provider = content.get("provider", {}).get("displayName", "Unknown")  # Extract Provider Name

        print(f"📰 {title}\n🔗 {link}\n📢 Source: {provider}\n")
else:
    print("No news articles found in the expected format.")
# Out:
# 📰 Tumbling Tesla sales in Europe are a concern, but RBC's Narayan still remains bullish
# 🔗 https://finance.yahoo.com/news/tumbling-tesla-sales-in-europe-are-a-concern-but-rbcs-narayan-still-remains-bullish-153002551.html
# 📢 Source: Yahoo Finance
#
# 📰 Why these investors stay bullish on Tesla
# 🔗 https://finance.yahoo.com/video/why-investors-stay-bullish-tesla-144451016.html
# 📢 Source: Yahoo Finance Video
#
# 📰 Cathie Wood Sticks to $2,600 Tesla Target Despite Sharp 2025 Drop
# 🔗 https://finance.yahoo.com/news/cathie-wood-sticks-2-600-152925682.html
# 📢 Source: GuruFocus.com
#
# 📰 Tesla, Inc. (TSLA): Among Cathie Wood’s Top AI Stock Picks in 2025
# 🔗 https://finance.yahoo.com/news/tesla-inc-tsla-among-cathie-152629900.html
# 📢 Source: Insider Monkey
#
# 📰 Private Equity Joins Fight to Overhaul Delaware Corporate Law
# 🔗 https://finance.yahoo.com/news/private-equity-joins-fight-overhaul-152623241.html
# 📢 Source: Bloomberg

# %%
import http.client
import json
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download VADER model (run once)
nltk.download("vader_lexicon")

# Initialize Sentiment Analyzer
sia = SentimentIntensityAnalyzer()

# Connect to API
conn = http.client.HTTPSConnection("yahoo-finance166.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "d3660ac08cmsh7ef855175840569p1828b7jsnb8a720203fb4",
    'x-rapidapi-host': "yahoo-finance166.p.rapidapi.com"
}

# API Request
conn.request("GET", "/api/news/list-by-symbol?s=AAPL%2CGOOGL%2CTSLA&region=US&snippetCount=5", headers=headers)
res = conn.getresponse()
data = res.read()

# Convert JSON response
try:
    news_data = json.loads(data.decode("utf-8"))  # Convert response to dictionary
except json.JSONDecodeError as e:
    print("Error parsing JSON:", e)
    exit()

# Extract & analyze news sentiment
if "data" in news_data and "main" in news_data["data"] and "stream" in news_data["data"]["main"]:
    articles = news_data["data"]["main"]["stream"]  # Extract list of articles

    for item in articles:
        content = item.get("content", {})  # Extract content dictionary
        title = content.get("title", "No Title")  # Extract title

        # Ensure URL exists before extracting it
        click_url = content.get("clickThroughUrl")
        link = click_url["url"] if click_url and "url" in click_url else None

        if not link:
            continue  # Skip articles with no valid link

        provider = content.get("provider", {}).get("displayName", "Unknown")  # Extract Provider Name

        # **Sentiment Analysis**
        sentiment_score = sia.polarity_scores(title)["compound"]

        # **Decision Based on Sentiment**
        if sentiment_score > 0.05:
            decision = "✅ Invest (Positive Sentiment)"
        elif sentiment_score < -0.05:
            decision = "❌ Don't Invest (Negative Sentiment)"
        else:
            decision = "🤔 Hold (Neutral Sentiment)"

        print(f"📰 {title}\n🔗 {link}\n📢 Source: {provider}\n📊 Sentiment Score: {sentiment_score}\n💡 Decision: {decision}\n")
else:
    print("No news articles found in the expected format.")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\pande\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# 📰 Tumbling Tesla sales in Europe are a concern, but RBC's Narayan still remains bullish
# 🔗 https://finance.yahoo.com/news/tumbling-tesla-sales-in-europe-are-a-concern-but-rbcs-narayan-still-remains-bullish-153002551.html
# 📢 Source: Yahoo Finance
# 📊 Sentiment Score: 0.0
# 💡 Decision: 🤔 Hold (Neutral Sentiment)
#
# 📰 Why these investors stay bullish on Tesla
# 🔗 https://finance.yahoo.com/video/why-investors-stay-bullish-tesla-144451016.html
# 📢 Source: Yahoo Finance Video
# 📊 Sentiment Score: 0.0
# 💡 Decision: 🤔 Hold (Neutral Sentiment)
#
# 📰 Cathie Wood Sticks to $2,600 Tesla Target Despite Sharp 2025 Drop
# 🔗 https://finance.yahoo.com/news/cathie-wood-sticks-2-600-152925682.html
# 📢 Source: GuruFocus.com
# 📊 Sentiment Score: 0.2057
# 💡 Decision: ✅ Invest (Positive Sentiment)
#
# 📰 Tesla, Inc. (TSLA): Among Cathie Wood’s Top AI Stock Picks in 2025
# 🔗 https://finance.yahoo.com/news/tesla-inc-tsla-among-cathie-152629900.html
# 📢 Source: Insider Monkey
# 📊 Sentiment Score: 0.2023
# 💡 Decision: ✅ Invest (Positive Sentiment)
#
# 📰 Private Equity Joins Fight to Overhaul Delaware Corporate Law
# 🔗 https://finance.yahoo.com/news/private-equity-joins-fight-overhaul-152623241.html
# 📢 Source: Bloomberg
# 📊 Sentiment Score: -0.3818
# 💡 Decision: ❌ Don't Invest (Negative Sentiment)

# %%
pip install transformers torch requests nltk yfinance
# Out:
# Requirement already satisfied: transformers in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (4.50.0)
# Requirement already satisfied: torch in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (2.6.0)
# Requirement already satisfied: requests in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (2.32.3)
# Requirement already satisfied: nltk in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (3.9.1)
# Requirement already satisfied: yfinance in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (0.2.54)
# Requirement already satisfied: filelock in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: click in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: colorama in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\pande\anaconda3\envs\machinelearning\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import login
login("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")

# %%
import requests
import torch
import time
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import numpy as np
import yfinance as yf

# Load FinBERT Model & Tokenizer
MODEL_NAME = "yiyanghkust/finbert-tone"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)

# Function to get news from Yahoo Finance with Rate Limiting Handling
def get_stock_news(symbol="RELIANCE.NS", news_count=5, retries=3):
    url = f"https://query2.finance.yahoo.com/v1/finance/search?q={symbol}&newsCount={news_count}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    for attempt in range(retries):
        response = requests.get(url, headers=headers)
        print("Response Status Code:", response.status_code)  # Debugging

        if response.status_code == 200:
            try:
                news_data = response.json().get("news", [])
                return [{"title": article["title"], "link": article.get("link", "#")} for article in news_data]
            except Exception as e:
                print("Error parsing JSON:", e)
                return []

        elif response.status_code == 429:
            print(f"Rate limited! Retrying in {2**attempt} seconds...")
            time.sleep(2**attempt)  # Exponential backoff (2s, 4s, 8s)

        else:
            print("Failed to fetch news. Status Code:", response.status_code)
            return []

    print("❌ Maximum retry attempts reached. Unable to fetch news.")
    return []

# Function to predict sentiment using FinBERT
def analyze_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    scores = torch.nn.functional.softmax(outputs.logits, dim=-1).numpy()[0]

    # Labels: 0 = Negative, 1 = Neutral, 2 = Positive
    sentiment_labels = ["Negative", "Neutral", "Positive"]
    return sentiment_labels[np.argmax(scores)], scores

# Function to aggregate sentiment across multiple news articles
def aggregate_sentiment(news_list):
    total_scores = np.zeros(3)  # [Negative, Neutral, Positive]

    for news in news_list:
        sentiment, scores = analyze_sentiment(news["title"])
        total_scores += scores  # Sum up scores

    avg_scores = total_scores / len(news_list)  # Take average
    sentiment_labels = ["Negative", "Neutral", "Positive"]
    final_sentiment = sentiment_labels[np.argmax(avg_scores)]

    return final_sentiment, avg_scores

# Function to get stock trend (Uptrend, Downtrend, or Neutral)
def get_stock_trend(symbol="TCS.NS"):
    stock = yf.Ticker(symbol)
    data = stock.history(period="5d")  # Get last 5 days of stock prices
    if len(data) < 2:
        return "No Data"

    latest_price = data["Close"].iloc[-1]  # Latest closing price
    prev_price = data["Close"].iloc[-2]   # Previous closing price

    if latest_price > prev_price:
        return "📈 Uptrend"
    elif latest_price < prev_price:
        return "📉 Downtrend"
    else:
        return "➖ Neutral"

# Fetch News & Analyze Sentiment
stock_symbol = "TCS.NS"
news_list = get_stock_news(stock_symbol)

if news_list:
    final_sentiment, avg_scores = aggregate_sentiment(news_list)
    stock_trend = get_stock_trend(stock_symbol)

    # Investment Decision based on sentiment & stock trend
    if final_sentiment == "Positive" and stock_trend == "📈 Uptrend":
        decision = "✅ Strong Buy (Positive Sentiment & Uptrend)"
    elif final_sentiment == "Positive" and stock_trend == "📉 Downtrend":
        decision = "🤔 Buy but Monitor (Positive Sentiment but Downtrend)"
    elif final_sentiment == "Neutral":
        decision = "🤔 Hold (Neutral Sentiment)"
    elif final_sentiment == "Negative" and stock_trend == "📉 Downtrend":
        decision = "❌ Sell (Negative Sentiment & Downtrend)"
    else:
        decision = "🤔 Hold (Check Again)"

    # Print final results
    print(f"\n Stock: {stock_symbol}")
    print(f" Average Sentiment: {final_sentiment}")
    print(f" Stock Trend: {stock_trend}")
    print(f" Investment Decision: {decision}")

else:
    print("⚠️ No news found for this stock.")
# Out:
# Response Status Code: 200
#
#  Stock: TCS.NS
#  Average Sentiment: Negative
#  Stock Trend: 📈 Uptrend
#  Investment Decision: 🤔 Hold (Check Again)

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Function to fetch stock trends & provide Buy/Hold/Sell suggestions
def get_stock_trends(symbols):
    trends = {}

    for symbol in symbols:
        stock = yf.Ticker(symbol)
        data = stock.history(period="5d")  # Get last 5 days of stock prices

        if len(data) < 2:
            trends[symbol] = {"trend": "No Data", "decision": "N/A", "data": None}
            continue

        latest_price = data["Close"].iloc[-1]  # Latest closing price
        prev_price = data["Close"].iloc[-2]   # Previous closing price

        if latest_price > prev_price:
            trend = "Uptrend"
            decision = "Buy (Trending Up)"
        elif latest_price < prev_price:
            trend = "Downtrend"
            decision = "Sell (Trending Down)"
        else:
            trend = "Neutral"
            decision = "Hold (No Significant Movement)"

        trends[symbol] = {"trend": trend, "decision": decision, "data": data}

    return trends

# Function to visualize stock trends
def plot_stock_trends(trends):
    plt.figure(figsize=(12, 6))

    for symbol, details in trends.items():
        if details["data"] is None:
            continue  # Skip if no data

        data = details["data"]
        plt.plot(data.index, data["Close"], label=f"{symbol} - {details['trend']}")

    plt.xlabel("Date")
    plt.ylabel("Stock Price (INR)")
    plt.title("Stock Price Trends Over the Last 5 Days")
    plt.legend()
    plt.grid(True)
    plt.show()

# List of multiple stock symbols (Indian stocks on NSE)
stock_symbols = ["RELIANCE.NS", "TCS.NS", "INFY.NS", "HDFCBANK.NS", "HINDUNILVR.NS"]

# Get trends for all stocks
stock_trends = get_stock_trends(stock_symbols)

# Display results
print("\n📊 **Stock Market Trends & Recommendations:**")
for stock, details in stock_trends.items():
    print(f"🔹 {stock}: {details['trend']} | {details['decision']}")

# Visualize stock trends
plot_stock_trends(stock_trends)
# Out:
# 📊 **Stock Market Trends & Recommendations:**
# 🔹 RELIANCE.NS: Downtrend | Sell (Trending Down)
# 🔹 TCS.NS: Uptrend | Buy (Trending Up)
# 🔹 INFY.NS: Uptrend | Buy (Trending Up)
# 🔹 HDFCBANK.NS: Uptrend | Buy (Trending Up)
# 🔹 HINDUNILVR.NS: Uptrend | Buy (Trending Up)
